# %% [markdown]
# # Sherlock (Context Classification)
# ### Ken Smith
# The Sherlock service gives the context of a list of objects in the sky based on numerous large catalogues (e.g. Pan-STARRS1, Gaia DR2, etc.).  The service can also accept an arbitrary position in the sky.
#
# Demonstrates usage of:
# * /sherlock/objects/
# * /sherlock/position/
#
#
# ### Python (3 only) requirements - pip install
# lasair

# %% [markdown]
# ### Grab my Lasair API token
# Get your token before you start.  If you haven't got a Lasair account you can register here: https://lasair-iris.roe.ac.uk/signup.  Use the curl command below to get your token & set the last line of the next cell to be your token ID.
#
# ```bash
# curl --data "username=tutorial&password=***********" https://lasair-iris.roe.ac.uk/api/auth-token/
# ```
# You should get the following response:
# ```json
# {"token":"acf14c2788ec5d7abb351f06e9ce2624a810b2ab"}
# ```
# We can use this token temporarily, but note that it will be disabled after the workshop!

# %%
from lasair import LasairError, lasair_client as lasair
import json

token = "acf14c2788ec5d7abb351f06e9ce2624a810b2ab"

# %% [markdown]
# ### Get a bunch of objects
# Why not just grab a few objects from one of the topics (e.g. the 2SN-likecandidates topic)

# %%
topic = "2SN-likecandidates"

L = lasair(token)

try:
    result = L.streams(topic, limit=10)
except LasairError as e:
    print(e)

objectIds = [row['objectId'] for row in result]

# %% [markdown]
# ### Now get Sherlock info for these objects

# %%
try:
    result = L.sherlock_objects(objectIds, lite = True)
except LasairError as e:
    print(e)

for k, v in result['classifications'].items():
    print(k, json.dumps(v, indent=2))

for row in result['crossmatches']:
    print(json.dumps(row, indent=2))

print(len(result['crossmatches']))
# Out:
# ZTF19aanvddi [
#   "SN",
#   "The transient is possibly associated with <em><a href=\"http://skyserver.sdss.org/dr12/en/tools/explore/Summary.aspx?id=1237654879137301121\">SDSS J155848.62+015432.0</a></em>; an r=20.68 mag galaxy found in the SDSS/PS1 catalogues. It's located 0.11\" S, 0.11\" W from the galaxy centre."
# ]
# ZTF19aashasy [
#   "NT",
#   "The transient is synonymous with <em><a href=\"http://skyserver.sdss.org/dr12/en/tools/explore/Summary.aspx?id=1237665441539883454\">SDSS J164633.73+123518.0</a></em>; a G=19.38 mag galaxy found in the SDSS/GAIA catalogues. It's located 0.2\" from the galaxy core."
# ]
# ZTF19abdgkrk [
#   "NT",
#   "The transient is synonymous with <em>S8J6000253</em>; a B=15.98 mag galaxy found in the GSC/GAIA/PS1/2MASS/GLADE catalogues. It's located 0.0\" (0.1 Kpc) from the galaxy core. A host distance of 259.4 Mpc(z=0.058) implies a <em>m - M =</em> 37.07."
# ]
# ZTF19abqmptj [
#   "NT",
#   "The transient is synonymous with <em><a href=\"http://skyserver.sdss.org/dr12/en/tools/explore/Summary.aspx?id=1237668650931126947\">SDSS J164333.38-063245.4</a></em>; a B=16.84 mag galaxy found in the SDSS/2MASS/GAIA/GLADE catalogues. It's located 0.1\" from the galaxy core."
# ]
# ZTF20aacdjms [
#   "NT",
#   "The transient is synonymous with <em>16110655-0539499</em>; a B=17.24 mag stellar source found in the 2MASS/GAIA/GLADE catalogues. It's located 0.2\" from the stellar source core."
# ]
# ZTF20aagmrlz [
#   "NT",
#   "The transient is synonymous with <em><a href=\"http://skyserver.sdss.org/dr12/en/tools/explore/Summary.aspx?id=1237654879673385290\">SDSS J155154.16+022844.8</a></em>; a J=16.46 mag galaxy found in the SDSS/2MASS/GAIA catalogues. It's located 0.3\" from the galaxy core."
# ]
# ZTF20aavzczp [
#   "NT",
#   "The transient is synonymous with <em>16300562-0919108</em>; a J=15.86 mag stellar source found in the 2MASS/GAIA catalogues. It's located 0.4\" from the stellar source core."
# ]
# ZTF21aaloalc [
#   "NT",
#   "The transient is synonymous with <em><a href=\"https://ned.ipac.caltech.edu/cgi-bin/objsearch?objname=SDSSJ155017.11+082132.9&extend=no&hconst=73&omegam=0.27&omegav=0.73&corr_z=1&out_csys=Equatorial&out_equinox=J2000.0&obj_sort=RA+or+Longitude&of=pre_text&zv_breaker=30000.0&list_limit=5&img_stamp=YES\">SDSSJ155017.11+082132.9</a></em>; a B=18.41 mag galaxy found in the NED/SDSS/GLADE catalogues. It's located 0.9\" (1.1 Kpc) from the galaxy core. A host distance of 264.8 Mpc(z=0.059) implies a <em>m - M =</em> 37.11."
# ]
# ZTF21aanrvcq [
#   "SN",
#   "The transient is possibly associated with <em><a href=\"http://skyserver.sdss.org/dr12/en/tools/explore/Summary.aspx?id=1237668272455156300\">SDSS J163312+093404.7</a></em>; a B=16.96 mag galaxy found in the SDSS/2MASS/GLADE/PS1 catalogues. It's located 3.29\" S, 10.54\" W from the galaxy centre."
# ]
# ZTF21aaqupdt [
#   "NT",
#   "The transient is synonymous with <em><a href=\"http://skyserver.sdss.org/dr12/en/tools/explore/Summary.aspx?id=1237662237488906668\">SDSS J154704.37+060639.3</a></em>; a B=17.25 mag galaxy found in the SDSS/2MASS/GLADE catalogues. It's located 0.3\" (0.4 Kpc) from the galaxy core. A host z=0.080 implies a <em>m - M =</em> 37.81."
# ]
# {
#   "catalogue_object_id": "1237654879137301121",
#   "_g": 20.97570037841797,
#   "_gErr": 0.0056779999285936356,
#   "_r": 20.675500869750977,
#   "_rErr": 0.004592000041157007,
#   "_i": 19.958799362182617,
#   "_iErr": 0.0023219999857246876,
#   "_z": 19.69729995727539,
#   "_zErr": 0.003140999935567379,
#   "_y": 19.58919906616211,
#   "_yErr": 0.0031399999279528856,
#   "separationArcsec": 0.10495291881523428,
#   "northSeparationArcsec": "0.1139976",
#   "eastSeparationArcsec": "0.1066280",
#   "association_type": "SN",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF19aanvddi",
#   "catalogue_table_name": "SDSS/PS1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "multiple",
#   "raDeg": 239.70260347453586,
#   "decDeg": 1.908912629240034,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": 0.707155,
#   "photoZErr": 0.081447,
#   "catalogue_object_subtype": "multiple",
#   "_u": 21.9981,
#   "_uErr": 0.409821,
#   "rankScore": 2005.0,
#   "rank": 1
# }
# {
#   "catalogue_object_id": 110292397026231177,
#   "_g": 20.97570037841797,
#   "_gErr": 0.0056779999285936356,
#   "_r": 20.675500869750977,
#   "_rErr": 0.004592000041157007,
#   "_i": 19.958799362182617,
#   "_iErr": 0.0023219999857246876,
#   "_z": 19.69729995727539,
#   "_zErr": 0.003140999935567379,
#   "_y": 19.58919906616211,
#   "_yErr": 0.0031399999279528856,
#   "separationArcsec": 0.1560885035534478,
#   "northSeparationArcsec": "0.1139976",
#   "eastSeparationArcsec": "0.1066280",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_ps1_dr1",
#   "transient_object_id": "ZTF19aanvddi",
#   "catalogue_table_name": "PanSTARRS DR1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "ps1 galaxy r angular",
#   "raDeg": 239.702609252,
#   "decDeg": 1.908927516,
#   "original_search_radius_arcsec": 6.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 2005.0,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": 3,
#   "catalogue_object_id": 1237654879137301121,
#   "photoZ": 0.707155,
#   "photoZErr": 0.081447,
#   "_u": 21.9981,
#   "_uErr": 0.409821,
#   "_g": 21.7295,
#   "_gErr": 0.167827,
#   "_r": 21.0683,
#   "_rErr": 0.125363,
#   "_i": 20.2413,
#   "_iErr": 0.109976,
#   "_z": 19.8958,
#   "_zErr": 0.237813,
#   "separationArcsec": 0.10495291881523428,
#   "northSeparationArcsec": "0.0604052641",
#   "eastSeparationArcsec": "0.0858406656",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_sdss_photo_stars_galaxies_dr12",
#   "transient_object_id": "ZTF19aanvddi",
#   "catalogue_table_name": "SDSS DR12 PhotoObjAll Table",
#   "catalogue_table_id": 47,
#   "catalogue_view_id": 13,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "sdss phot galaxy angular",
#   "raDeg": 239.70260347453586,
#   "decDeg": 1.908912629240034,
#   "original_search_radius_arcsec": 6.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 2005.0
# }
# {
#   "catalogue_object_id": "110292396990211845",
#   "_g": 19.421100616455078,
#   "_gErr": 0.0027749999426305294,
#   "_r": 18.71380043029785,
#   "_rErr": 0.0018609999679028988,
#   "_i": 18.292800903320312,
#   "_iErr": 0.0010779999429360032,
#   "_z": 18.269899368286133,
#   "_zErr": 0.0016280000563710928,
#   "_y": 17.954099655151367,
#   "_yErr": 0.001478999969549477,
#   "separationArcsec": 12.900046222462038,
#   "northSeparationArcsec": "2.0718936",
#   "eastSeparationArcsec": "-12.7325745",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_ps1_dr1",
#   "transient_object_id": "ZTF19aanvddi",
#   "catalogue_table_name": "PS1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "PS1",
#   "raDeg": 239.69904082600002,
#   "decDeg": 1.909471376,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "rankScore": 2005.0,
#   "rank": 2,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "1237665441539883454",
#   "G": 19.3809,
#   "separationArcsec": 0.16957724290997328,
#   "northSeparationArcsec": "0.03638",
#   "eastSeparationArcsec": "0.16564",
#   "association_type": "NT",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF19aashasy",
#   "catalogue_table_name": "SDSS/GAIA",
#   "catalogue_table_id": 79,
#   "catalogue_view_id": 46,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "multiple",
#   "raDeg": 251.64057527669002,
#   "decDeg": 12.588349671358172,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": 0.363948,
#   "photoZErr": 0.056823,
#   "_r": 19.0204,
#   "_rErr": 0.0224657,
#   "_g": 19.6187,
#   "_gErr": 0.0237488,
#   "_i": 18.8265,
#   "_iErr": 0.0291901,
#   "_z": 18.8559,
#   "_zErr": 0.111765,
#   "_u": 19.9523,
#   "_uErr": 0.0801761,
#   "catalogue_object_subtype": "multiple",
#   "rankScore": 1010.16957724291,
#   "rank": 1
# }
# {
#   "catalogue_object_id": 4448934211340368128,
#   "G": 19.3809,
#   "separationArcsec": 0.16957724290997328,
#   "northSeparationArcsec": "0.03638",
#   "eastSeparationArcsec": "0.16564",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_gaia_dr2",
#   "transient_object_id": "ZTF19aashasy",
#   "catalogue_table_name": "Gaia DR2",
#   "catalogue_table_id": 79,
#   "catalogue_view_id": 46,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "gaia star angular",
#   "raDeg": 251.64057527669002,
#   "decDeg": 12.588349671358172,
#   "original_search_radius_arcsec": 5.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.16957724291,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": 3,
#   "catalogue_object_id": 1237665441539883454,
#   "photoZ": 0.363948,
#   "photoZErr": 0.056823,
#   "_u": 19.9523,
#   "_uErr": 0.0801761,
#   "_g": 19.6187,
#   "_gErr": 0.0237488,
#   "_r": 19.0204,
#   "_rErr": 0.0224657,
#   "_i": 18.8265,
#   "_iErr": 0.0291901,
#   "_z": 18.8559,
#   "_zErr": 0.111765,
#   "separationArcsec": 0.22297795645253593,
#   "northSeparationArcsec": "0.11268",
#   "eastSeparationArcsec": "0.19239",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_sdss_photo_stars_galaxies_dr12",
#   "transient_object_id": "ZTF19aashasy",
#   "catalogue_table_name": "SDSS DR12 PhotoObjAll Table",
#   "catalogue_table_id": 47,
#   "catalogue_view_id": 13,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "sdss phot galaxy angular",
#   "raDeg": 251.64058289202936,
#   "decDeg": 12.588370867779203,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.16957724291
# }
# {
#   "catalogue_object_subtype": "multiple",
#   "catalogue_object_id": "S8J6000253",
#   "U": null,
#   "UErr": null,
#   "B": 15.9802,
#   "BErr": 0.389779,
#   "V": null,
#   "VErr": null,
#   "R": null,
#   "RErr": null,
#   "I": null,
#   "IErr": null,
#   "J": 14.03,
#   "JErr": 0.043,
#   "H": 13.232,
#   "HErr": 0.048,
#   "K": 12.22,
#   "KErr": 0.041,
#   "separationArcsec": 0.04346705771012647,
#   "northSeparationArcsec": "0.3901",
#   "eastSeparationArcsec": "-0.3938",
#   "association_type": "NT",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF19abdgkrk",
#   "catalogue_table_name": "GSC/GAIA/PS1/2MASS/GLADE",
#   "catalogue_table_id": 3,
#   "catalogue_view_id": 21,
#   "classificationReliability": 1,
#   "scale": 1.1222305798031,
#   "distance": 259.0796712677433,
#   "distance_modulus": 37.0671666866465,
#   "major_axis_arcsec": null,
#   "direct_distance": 259.418,
#   "direct_distance_scale": 1.2576939567673993,
#   "direct_distance_modulus": 37.070000533941965,
#   "catalogue_object_type": "galaxy",
#   "search_name": "multiple",
#   "raDeg": 250.343821,
#   "decDeg": -20.009384,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": 0.05466825580048584,
#   "merged_rank": null,
#   "z": 0.0579449089725,
#   "photoZ": null,
#   "photoZErr": null,
#   "G": 16.2762,
#   "_r": 16.001399993896484,
#   "_rErr": 0.0005450000171549618,
#   "_g": 16.631799697875977,
#   "_gErr": 0.000699999975040555,
#   "_i": 15.59060001373291,
#   "_iErr": 0.0004220000118948519,
#   "_z": 15.29640007019043,
#   "_zErr": 0.0004600000102072954,
#   "_y": 15.180999755859375,
#   "_yErr": 0.0004290000069886446,
#   "rankScore": 952.00273341279,
#   "rank": 1
# }
# {
#   "catalogue_object_subtype": 0,
#   "catalogue_object_id": "S8J6000253",
#   "U": null,
#   "UErr": null,
#   "B": 15.9802,
#   "BErr": 0.389779,
#   "V": null,
#   "VErr": null,
#   "R": null,
#   "RErr": null,
#   "I": null,
#   "IErr": null,
#   "J": null,
#   "JErr": null,
#   "H": null,
#   "HErr": null,
#   "K": null,
#   "KErr": null,
#   "separationArcsec": 0.5542774261661071,
#   "northSeparationArcsec": "0.3901",
#   "eastSeparationArcsec": "-0.3938",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_guide_star_catalogue_v2_3",
#   "transient_object_id": "ZTF19abdgkrk",
#   "catalogue_table_name": "GSC v2.3",
#   "catalogue_table_id": 3,
#   "catalogue_view_id": 21,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "GSC star 2 angular",
#   "raDeg": 250.3437007651595,
#   "decDeg": -20.00928715769518,
#   "original_search_radius_arcsec": 100.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 952.00273341279
# }
# {
#   "catalogue_object_id": 4130329654672846848,
#   "G": 16.2762,
#   "separationArcsec": 0.08097015695757864,
#   "northSeparationArcsec": "0.0472",
#   "eastSeparationArcsec": "-0.0659",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_gaia_dr2",
#   "transient_object_id": "ZTF19abdgkrk",
#   "catalogue_table_name": "Gaia DR2",
#   "catalogue_table_id": 79,
#   "catalogue_view_id": 46,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "gaia star angular",
#   "raDeg": 250.34379769130322,
#   "decDeg": -20.009382402348596,
#   "original_search_radius_arcsec": 5.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 952.00273341279,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": 83982503438329143,
#   "_g": 16.631799697875977,
#   "_gErr": 0.000699999975040555,
#   "_r": 16.001399993896484,
#   "_rErr": 0.0005450000171549618,
#   "_i": 15.59060001373291,
#   "_iErr": 0.0004220000118948519,
#   "_z": 15.29640007019043,
#   "_zErr": 0.0004600000102072954,
#   "_y": 15.180999755859375,
#   "_yErr": 0.0004290000069886446,
#   "separationArcsec": 0.19572246427953863,
#   "northSeparationArcsec": "0.1902",
#   "eastSeparationArcsec": "0.0461",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_galaxy_ps1_dr1",
#   "transient_object_id": "ZTF19abdgkrk",
#   "catalogue_table_name": "PanSTARRS DR1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "ps1 galaxy i angular",
#   "raDeg": 250.343830808,
#   "decDeg": -20.009342682,
#   "original_search_radius_arcsec": 100.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 952.00273341279,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "16412251-2000337 ",
#   "J": 14.03,
#   "JErr": 0.043,
#   "H": 13.232,
#   "HErr": 0.048,
#   "K": 12.22,
#   "KErr": 0.041,
#   "separationArcsec": 0.04346705771012647,
#   "northSeparationArcsec": "0.0415",
#   "eastSeparationArcsec": "0.0130",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_2mass_psc_final",
#   "transient_object_id": "ZTF19abdgkrk",
#   "catalogue_table_name": "2MASS PSC",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "2mass star angular",
#   "raDeg": 250.343821,
#   "decDeg": -20.009384,
#   "original_search_radius_arcsec": 2.5,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 952.00273341279,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": "G",
#   "catalogue_object_id": "3096990",
#   "z": 0.0579449089725,
#   "distance": 259.0796712677433,
#   "B": null,
#   "BErr": null,
#   "J": null,
#   "JErr": null,
#   "H": null,
#   "HErr": null,
#   "K": null,
#   "KErr": null,
#   "separationArcsec": 0.7058212364462867,
#   "northSeparationArcsec": "-0.3",
#   "eastSeparationArcsec": "0.6",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_glade_v2_3",
#   "transient_object_id": "ZTF19abdgkrk",
#   "catalogue_table_name": "The GLADE Catalogue v2.3",
#   "catalogue_table_id": 78,
#   "catalogue_view_id": 44,
#   "classificationReliability": 1,
#   "scale": 1.1222305798031,
#   "distance_modulus": 37.0671666866465,
#   "major_axis_arcsec": null,
#   "direct_distance": 259.418,
#   "direct_distance_scale": 1.2576939567673993,
#   "direct_distance_modulus": 37.070000533941965,
#   "catalogue_object_type": "galaxy",
#   "search_name": "glade spec galaxy physical (direct distance)",
#   "raDeg": 250.344,
#   "decDeg": -20.00949,
#   "original_search_radius_arcsec": 39.75529955515808,
#   "physical_separation_kpc": 0.8877071036365883,
#   "merged_rank": 1,
#   "rankScore": 952.00273341279
# }
# {
#   "catalogue_object_id": "1237668650931126947",
#   "J": 15.49,
#   "JErr": 0.077,
#   "H": 14.517,
#   "HErr": 0.072,
#   "K": 13.439,
#   "KErr": 0.049,
#   "separationArcsec": 0.10664941789795435,
#   "northSeparationArcsec": "0.18261",
#   "eastSeparationArcsec": "-0.16085",
#   "association_type": "NT",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF19abqmptj",
#   "catalogue_table_name": "SDSS/2MASS/GAIA/GLADE",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "multiple",
#   "raDeg": 250.88911153709296,
#   "decDeg": -6.545948099233311,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": 0.148586,
#   "photoZErr": 0.022581,
#   "G": 18.9767,
#   "catalogue_object_subtype": "multiple",
#   "_r": 17.7966,
#   "_rErr": 0.0157734,
#   "_g": 18.802,
#   "_gErr": 0.0265399,
#   "_i": 17.0992,
#   "_iErr": 0.0136136,
#   "_z": 16.7253,
#   "_zErr": 0.0332228,
#   "_u": 19.8296,
#   "_uErr": 0.160815,
#   "B": 16.836,
#   "BErr": null,
#   "rankScore": 1010.106649417898,
#   "rank": 1
# }
# {
#   "catalogue_object_id": "16433337-0632453 ",
#   "J": 15.49,
#   "JErr": 0.077,
#   "H": 14.517,
#   "HErr": 0.072,
#   "K": 13.439,
#   "KErr": 0.049,
#   "separationArcsec": 0.24335730140434988,
#   "northSeparationArcsec": "0.18261",
#   "eastSeparationArcsec": "-0.16085",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_2mass_psc_final",
#   "transient_object_id": "ZTF19abqmptj",
#   "catalogue_table_name": "2MASS PSC",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "2mass star angular",
#   "raDeg": 250.889067,
#   "decDeg": -6.545927,
#   "original_search_radius_arcsec": 2.5,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.106649417898,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": 4352777212207062400,
#   "G": 18.9767,
#   "separationArcsec": 0.11288889466995759,
#   "northSeparationArcsec": "0.08526",
#   "eastSeparationArcsec": "-0.07403",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_gaia_dr2",
#   "transient_object_id": "ZTF19abqmptj",
#   "catalogue_table_name": "Gaia DR2",
#   "catalogue_table_id": 79,
#   "catalogue_view_id": 46,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "gaia star angular",
#   "raDeg": 250.88909127718725,
#   "decDeg": -6.545954042384524,
#   "original_search_radius_arcsec": 5.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.106649417898,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": 3,
#   "catalogue_object_id": 1237668650931126947,
#   "photoZ": 0.148586,
#   "photoZErr": 0.022581,
#   "_u": 19.8296,
#   "_uErr": 0.160815,
#   "_g": 18.802,
#   "_gErr": 0.0265399,
#   "_r": 17.7966,
#   "_rErr": 0.0157734,
#   "_i": 17.0992,
#   "_iErr": 0.0136136,
#   "_z": 16.7253,
#   "_zErr": 0.0332228,
#   "separationArcsec": 0.10664941789795435,
#   "northSeparationArcsec": "0.10665",
#   "eastSeparationArcsec": "-0.00157",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_sdss_photo_stars_galaxies_dr12",
#   "transient_object_id": "ZTF19abqmptj",
#   "catalogue_table_name": "SDSS DR12 PhotoObjAll Table",
#   "catalogue_table_id": 47,
#   "catalogue_view_id": 13,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "sdss phot galaxy angular",
#   "raDeg": 250.88911153709296,
#   "decDeg": -6.545948099233311,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.106649417898
# }
# {
#   "catalogue_object_id": "16433335-0632450",
#   "J": 14.861,
#   "JErr": 0.136,
#   "H": 14.028,
#   "HErr": 0.14,
#   "K": 13.15,
#   "KErr": 0.115,
#   "separationArcsec": 0.6880987629387868,
#   "northSeparationArcsec": "0.4310",
#   "eastSeparationArcsec": "-0.5364",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_2mass_xsc_final",
#   "transient_object_id": "ZTF19abqmptj",
#   "catalogue_table_name": "2MASS XSC",
#   "catalogue_table_id": 2,
#   "catalogue_view_id": 10,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "2mass galaxy angular",
#   "raDeg": 250.888962,
#   "decDeg": -6.545858,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.106649417898,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": "G",
#   "catalogue_object_id": "16433335-0632450",
#   "z": null,
#   "distance": null,
#   "B": 16.836,
#   "BErr": null,
#   "J": 15.029,
#   "JErr": 0.086,
#   "H": 14.07,
#   "HErr": 0.079,
#   "K": 13.23,
#   "KErr": 0.075,
#   "separationArcsec": 0.6880987629387868,
#   "northSeparationArcsec": "0.4310",
#   "eastSeparationArcsec": "-0.5364",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_glade_v2_3",
#   "transient_object_id": "ZTF19abqmptj",
#   "catalogue_table_name": "The GLADE Catalogue v2.3",
#   "catalogue_table_id": 78,
#   "catalogue_view_id": 44,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "glade phot galaxy angular",
#   "raDeg": 250.888962,
#   "decDeg": -6.545858,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.106649417898
# }
# {
#   "catalogue_object_id": "16110655-0539499",
#   "J": 15.635,
#   "JErr": 0.1,
#   "H": 14.94,
#   "HErr": 0.115,
#   "K": 14.402,
#   "KErr": 0.094,
#   "separationArcsec": 0.17715159217532955,
#   "northSeparationArcsec": "0.0669",
#   "eastSeparationArcsec": "-0.1909",
#   "association_type": "NT",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF20aacdjms",
#   "catalogue_table_name": "2MASS/GAIA/GLADE",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "multiple",
#   "raDeg": 242.77733162099378,
#   "decDeg": -5.663892860097674,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "G": 19.5282,
#   "catalogue_object_subtype": "multiple",
#   "B": 17.241,
#   "BErr": null,
#   "rankScore": 1010.1771515921753,
#   "rank": 1
# }
# {
#   "catalogue_object_id": "16110655-0539499 ",
#   "J": 15.635,
#   "JErr": 0.1,
#   "H": 14.94,
#   "HErr": 0.115,
#   "K": 14.402,
#   "KErr": 0.094,
#   "separationArcsec": 0.2022970128188543,
#   "northSeparationArcsec": "0.0669",
#   "eastSeparationArcsec": "-0.1909",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_2mass_psc_final",
#   "transient_object_id": "ZTF20aacdjms",
#   "catalogue_table_name": "2MASS PSC",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "2mass star angular",
#   "raDeg": 242.777327,
#   "decDeg": -5.663883,
#   "original_search_radius_arcsec": 2.5,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.1771515921753,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": 4350173053277393920,
#   "G": 19.5282,
#   "separationArcsec": 0.17715159217532955,
#   "northSeparationArcsec": "0.031419",
#   "eastSeparationArcsec": "-0.174344",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_gaia_dr2",
#   "transient_object_id": "ZTF20aacdjms",
#   "catalogue_table_name": "Gaia DR2",
#   "catalogue_table_id": 79,
#   "catalogue_view_id": 46,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "gaia star angular",
#   "raDeg": 242.77733162099378,
#   "decDeg": -5.663892860097674,
#   "original_search_radius_arcsec": 5.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.1771515921753,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "16110656-0539496",
#   "J": 15.088,
#   "JErr": 0.24,
#   "H": 13.991,
#   "HErr": 0.205,
#   "K": 13.449,
#   "KErr": 0.2,
#   "separationArcsec": 0.41670605726907006,
#   "northSeparationArcsec": "0.4161",
#   "eastSeparationArcsec": "-0.0225",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_2mass_xsc_final",
#   "transient_object_id": "ZTF20aacdjms",
#   "catalogue_table_name": "2MASS XSC",
#   "catalogue_table_id": 2,
#   "catalogue_view_id": 10,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "2mass galaxy angular",
#   "raDeg": 242.777374,
#   "decDeg": -5.663786,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.1771515921753,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": "G",
#   "catalogue_object_id": "16110656-0539496",
#   "z": null,
#   "distance": null,
#   "B": 17.241,
#   "BErr": null,
#   "J": 15.128,
#   "JErr": 0.135,
#   "H": 14.252,
#   "HErr": 0.143,
#   "K": 13.719,
#   "KErr": 0.14,
#   "separationArcsec": 0.41670605726907006,
#   "northSeparationArcsec": "0.4161",
#   "eastSeparationArcsec": "-0.0225",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_glade_v2_3",
#   "transient_object_id": "ZTF20aacdjms",
#   "catalogue_table_name": "The GLADE Catalogue v2.3",
#   "catalogue_table_id": 78,
#   "catalogue_view_id": 44,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "glade phot galaxy angular",
#   "raDeg": 242.777374,
#   "decDeg": -5.663786,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.1771515921753
# }
# {
#   "catalogue_object_id": "1237654879673385290",
#   "J": 16.459,
#   "JErr": 0.109,
#   "H": 15.957,
#   "HErr": 0.154,
#   "K": 15.09,
#   "KErr": 0.139,
#   "separationArcsec": 0.3010858638075168,
#   "northSeparationArcsec": "-0.263",
#   "eastSeparationArcsec": "-0.622",
#   "association_type": "NT",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF20aagmrlz",
#   "catalogue_table_name": "SDSS/2MASS/GAIA",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "multiple",
#   "raDeg": 237.9756746150517,
#   "decDeg": 2.4791210995132906,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": 0.316305,
#   "photoZErr": 0.030645,
#   "_r": 18.5754,
#   "_rErr": 0.0219624,
#   "_g": 19.3537,
#   "_gErr": 0.0250389,
#   "_i": 18.2514,
#   "_iErr": 0.0323072,
#   "_z": 17.8376,
#   "_zErr": 0.0512743,
#   "_u": 19.9536,
#   "_uErr": 0.0833477,
#   "catalogue_object_subtype": "multiple",
#   "G": 18.822,
#   "rankScore": 1010.3010858638075,
#   "rank": 1
# }
# {
#   "catalogue_object_id": "15515413+0228446 ",
#   "J": 16.459,
#   "JErr": 0.109,
#   "H": 15.957,
#   "HErr": 0.154,
#   "K": 15.09,
#   "KErr": 0.139,
#   "separationArcsec": 0.6754198944643117,
#   "northSeparationArcsec": "-0.263",
#   "eastSeparationArcsec": "-0.622",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_2mass_psc_final",
#   "transient_object_id": "ZTF20aagmrlz",
#   "catalogue_table_name": "2MASS PSC",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "2mass star angular",
#   "raDeg": 237.975579,
#   "decDeg": 2.47908,
#   "original_search_radius_arcsec": 2.5,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.3010858638075,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": 3,
#   "catalogue_object_id": 1237654879673385290,
#   "photoZ": 0.316305,
#   "photoZErr": 0.030645,
#   "_u": 19.9536,
#   "_uErr": 0.0833477,
#   "_g": 19.3537,
#   "_gErr": 0.0250389,
#   "_r": 18.5754,
#   "_rErr": 0.0219624,
#   "_i": 18.2514,
#   "_iErr": 0.0323072,
#   "_z": 17.8376,
#   "_zErr": 0.0512743,
#   "separationArcsec": 0.32580002340964204,
#   "northSeparationArcsec": "-0.126145",
#   "eastSeparationArcsec": "-0.300374",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_sdss_photo_stars_galaxies_dr12",
#   "transient_object_id": "ZTF20aagmrlz",
#   "catalogue_table_name": "SDSS DR12 PhotoObjAll Table",
#   "catalogue_table_id": 47,
#   "catalogue_view_id": 13,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "sdss phot galaxy angular",
#   "raDeg": 237.9756684246354,
#   "decDeg": 2.4791180897699716,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.3010858638075
# }
# {
#   "catalogue_object_id": 4423336829031096064,
#   "G": 18.822,
#   "separationArcsec": 0.3010858638075168,
#   "northSeparationArcsec": "-0.115310",
#   "eastSeparationArcsec": "-0.278109",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_gaia_dr2",
#   "transient_object_id": "ZTF20aagmrlz",
#   "catalogue_table_name": "Gaia DR2",
#   "catalogue_table_id": 79,
#   "catalogue_view_id": 46,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "gaia star angular",
#   "raDeg": 237.9756746150517,
#   "decDeg": 2.4791210995132906,
#   "original_search_radius_arcsec": 5.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.3010858638075,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "16300562-0919108",
#   "J": 15.856,
#   "JErr": 0.075,
#   "H": 15.13,
#   "HErr": 0.079,
#   "K": 14.157,
#   "KErr": 0.064,
#   "separationArcsec": 0.393418896192794,
#   "northSeparationArcsec": "0.2288",
#   "eastSeparationArcsec": "-0.4851",
#   "association_type": "NT",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF20aavzczp",
#   "catalogue_table_name": "2MASS/GAIA",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "multiple",
#   "raDeg": 247.52348302954317,
#   "decDeg": -9.319708883121141,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": null,
#   "photoZErr": null,
#   "G": 18.9536,
#   "catalogue_object_subtype": "multiple",
#   "rankScore": 1010.3934188961928,
#   "rank": 1
# }
# {
#   "catalogue_object_id": "16300562-0919108 ",
#   "J": 15.856,
#   "JErr": 0.075,
#   "H": 15.13,
#   "HErr": 0.079,
#   "K": 14.157,
#   "KErr": 0.064,
#   "separationArcsec": 0.536320788832454,
#   "northSeparationArcsec": "0.2288",
#   "eastSeparationArcsec": "-0.4851",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_2mass_psc_final",
#   "transient_object_id": "ZTF20aavzczp",
#   "catalogue_table_name": "2MASS PSC",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "2mass star angular",
#   "raDeg": 247.523448,
#   "decDeg": -9.319689,
#   "original_search_radius_arcsec": 2.5,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.3934188961928,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": 4350485731192626944,
#   "G": 18.9536,
#   "separationArcsec": 0.393418896192794,
#   "northSeparationArcsec": "0.15720",
#   "eastSeparationArcsec": "-0.36065",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_gaia_dr2",
#   "transient_object_id": "ZTF20aavzczp",
#   "catalogue_table_name": "Gaia DR2",
#   "catalogue_table_id": 79,
#   "catalogue_view_id": 46,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "gaia star angular",
#   "raDeg": 247.52348302954317,
#   "decDeg": -9.319708883121141,
#   "original_search_radius_arcsec": 5.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.3934188961928,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_id": "16300560-0919105",
#   "J": 15.61,
#   "JErr": 0.149,
#   "H": 14.729,
#   "HErr": 0.131,
#   "K": 14.023,
#   "KErr": 0.144,
#   "separationArcsec": 1.021739399031027,
#   "northSeparationArcsec": "0.57078",
#   "eastSeparationArcsec": "-0.84744",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_2mass_xsc_final",
#   "transient_object_id": "ZTF20aavzczp",
#   "catalogue_table_name": "2MASS XSC",
#   "catalogue_table_id": 2,
#   "catalogue_view_id": 10,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "2mass galaxy angular",
#   "raDeg": 247.523346,
#   "decDeg": -9.319594,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 1010.3934188961928,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": "multiple",
#   "catalogue_object_id": "SDSSJ155017.11+082132.9",
#   "z": 0.059469,
#   "unkMag": 18.1,
#   "separationArcsec": 0.8628183583220372,
#   "northSeparationArcsec": "-0.819",
#   "eastSeparationArcsec": "-0.333",
#   "association_type": "NT",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF21aaloalc",
#   "catalogue_table_name": "NED/SDSS/GLADE",
#   "catalogue_table_id": 68,
#   "catalogue_view_id": 29,
#   "classificationReliability": 1,
#   "scale": 1.149682,
#   "distance": 266.182481,
#   "distance_modulus": 37.125897,
#   "major_axis_arcsec": 10.799999999999999,
#   "direct_distance": 264.809,
#   "direct_distance_scale": 1.2838302623473248,
#   "direct_distance_modulus": 37.114663706404684,
#   "catalogue_object_type": "galaxy",
#   "search_name": "multiple",
#   "raDeg": 237.57131084311345,
#   "decDeg": 8.359139503031818,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": 1.1077123193226692,
#   "merged_rank": null,
#   "photoZ": 0.054818,
#   "photoZErr": 0.015223,
#   "_r": 17.7849,
#   "_rErr": 0.0200586,
#   "_g": 18.1738,
#   "_gErr": 0.0160509,
#   "_i": 17.5256,
#   "_iErr": 0.0195157,
#   "_z": 17.4237,
#   "_zErr": 0.067483,
#   "_u": 19.2833,
#   "_uErr": 0.0885409,
#   "B": 18.41,
#   "BErr": 0.5,
#   "rankScore": 952.0553856159661,
#   "rank": 1
# }
# {
#   "catalogue_object_subtype": "G",
#   "catalogue_object_id": "SDSS J155017.11+082132.9",
#   "z": 0.059469,
#   "unkMag": 18.1,
#   "separationArcsec": 0.8844398083824742,
#   "northSeparationArcsec": "-0.819",
#   "eastSeparationArcsec": "-0.333",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_ned_stream",
#   "transient_object_id": "ZTF21aaloalc",
#   "catalogue_table_name": "NED",
#   "catalogue_table_id": 68,
#   "catalogue_view_id": 29,
#   "classificationReliability": 1,
#   "scale": 1.149682,
#   "distance": 266.182481,
#   "distance_modulus": 37.125897,
#   "major_axis_arcsec": 10.799999999999999,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "ned spec galaxy physical (within 1.2 * major axis) (redshift distance)",
#   "raDeg": 237.5712917,
#   "decDeg": 8.35914,
#   "original_search_radius_arcsec": 43.490286879328366,
#   "physical_separation_kpc": 1.0168245277807797,
#   "merged_rank": 1,
#   "rankScore": 952.0553856159661
# }
# {
#   "catalogue_object_subtype": 3,
#   "catalogue_object_id": 1237662635837555236,
#   "photoZ": 0.054818,
#   "photoZErr": 0.015223,
#   "_u": 19.2833,
#   "_uErr": 0.0885409,
#   "_g": 18.1738,
#   "_gErr": 0.0160509,
#   "_r": 17.7849,
#   "_rErr": 0.0200586,
#   "_i": 17.5256,
#   "_iErr": 0.0195157,
#   "_z": 17.4237,
#   "_zErr": 0.067483,
#   "separationArcsec": 0.8628183583220372,
#   "northSeparationArcsec": "-0.8212616",
#   "eastSeparationArcsec": "-0.2645515",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_sdss_photo_stars_galaxies_dr12",
#   "transient_object_id": "ZTF21aaloalc",
#   "catalogue_table_name": "SDSS DR12 PhotoObjAll Table",
#   "catalogue_table_id": 47,
#   "catalogue_view_id": 13,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "sdss phot galaxy angular",
#   "raDeg": 237.57131084311345,
#   "decDeg": 8.359139503031818,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 952.0553856159661
# }
# {
#   "catalogue_object_subtype": 3,
#   "catalogue_object_id": 1237662635837555236,
#   "z": 0.0593869,
#   "_u": 19.2833,
#   "_uErr": 0.0885409,
#   "_g": 18.1738,
#   "_gErr": 0.0160509,
#   "_r": 17.7849,
#   "_rErr": 0.0200586,
#   "_i": 17.5256,
#   "_iErr": 0.0195157,
#   "_z": 17.4237,
#   "_zErr": 0.067483,
#   "separationArcsec": 0.8628183583220372,
#   "northSeparationArcsec": "-0.8212616",
#   "eastSeparationArcsec": "-0.2645515",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_sdss_spect_galaxies_qsos_dr12",
#   "transient_object_id": "ZTF21aaloalc",
#   "catalogue_table_name": "SDSS DR12 SpecObjAll Table",
#   "catalogue_table_id": 48,
#   "catalogue_view_id": 14,
#   "classificationReliability": 1,
#   "scale": 1.148206,
#   "distance": 265.7994968,
#   "distance_modulus": 37.1227708,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "sdss spec sn physical (redshift distance)",
#   "raDeg": 237.57131084311345,
#   "decDeg": 8.359139503031818,
#   "original_search_radius_arcsec": 43.546192930536854,
#   "physical_separation_kpc": 0.9906932159355132,
#   "merged_rank": 1,
#   "rankScore": 952.0553856159661
# }
# {
#   "catalogue_object_subtype": "G",
#   "catalogue_object_id": "SDSSJ155017.11+082132.9",
#   "z": 0.0592385096193,
#   "distance": 265.1073849076869,
#   "B": 18.41,
#   "BErr": 0.5,
#   "J": null,
#   "JErr": null,
#   "H": null,
#   "HErr": null,
#   "K": null,
#   "KErr": null,
#   "separationArcsec": 1.4985800048123448,
#   "northSeparationArcsec": "-0.6",
#   "eastSeparationArcsec": "-1.4",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_glade_v2_3",
#   "transient_object_id": "ZTF21aaloalc",
#   "catalogue_table_name": "The GLADE Catalogue v2.3",
#   "catalogue_table_id": 78,
#   "catalogue_view_id": 44,
#   "classificationReliability": 1,
#   "scale": 1.1455371287051,
#   "distance_modulus": 37.117109128669,
#   "major_axis_arcsec": null,
#   "direct_distance": 264.809,
#   "direct_distance_scale": 1.2838302623473248,
#   "direct_distance_modulus": 37.114663706404684,
#   "catalogue_object_type": "galaxy",
#   "search_name": "glade spec galaxy physical (direct distance)",
#   "raDeg": 237.571,
#   "decDeg": 8.3592,
#   "original_search_radius_arcsec": 38.945958407758035,
#   "physical_separation_kpc": 1.9239223607266878,
#   "merged_rank": 1,
#   "rankScore": 952.0553856159661
# }
# {
#   "catalogue_object_id": "1237668272455156300",
#   "J": 14.122,
#   "JErr": 0.074,
#   "H": 13.255,
#   "HErr": 0.073,
#   "K": 12.824,
#   "KErr": 0.107,
#   "separationArcsec": 10.14845262426313,
#   "northSeparationArcsec": "3.294",
#   "eastSeparationArcsec": "10.542",
#   "association_type": "SN",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF21aanrvcq",
#   "catalogue_table_name": "SDSS/2MASS/GLADE/PS1",
#   "catalogue_table_id": 2,
#   "catalogue_view_id": 10,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "multiple",
#   "raDeg": 248.301,
#   "decDeg": 9.56798,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": null,
#   "merged_rank": null,
#   "z": null,
#   "photoZ": 0.0397,
#   "photoZErr": 0.03,
#   "B": 16.96,
#   "BErr": 0.43,
#   "catalogue_object_subtype": "multiple",
#   "_r": 17.7992000579834,
#   "_rErr": 0.0009009999921545386,
#   "_g": 18.356800079345703,
#   "_gErr": 0.0014890000456944108,
#   "_i": 17.216999053955078,
#   "_iErr": 0.0006230000290088356,
#   "_z": 17.18429946899414,
#   "_zErr": 0.0009449999779462814,
#   "_y": 16.924999237060547,
#   "_yErr": 0.0008699999889358878,
#   "_u": 18.1397,
#   "_uErr": 0.157775,
#   "rankScore": 2005.0,
#   "rank": 1
# }
# {
#   "catalogue_object_id": "16331229+0934051",
#   "J": 14.095,
#   "JErr": 0.148,
#   "H": 13.108,
#   "HErr": 0.131,
#   "K": 12.345,
#   "KErr": 0.131,
#   "separationArcsec": 11.044859193191256,
#   "northSeparationArcsec": "3.294",
#   "eastSeparationArcsec": "10.542",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_2mass_xsc_final",
#   "transient_object_id": "ZTF21aanrvcq",
#   "catalogue_table_name": "2MASS XSC",
#   "catalogue_table_id": 2,
#   "catalogue_view_id": 10,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "2mass galaxy angular",
#   "raDeg": 248.301224,
#   "decDeg": 9.56811,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 2005.0,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": "G",
#   "catalogue_object_id": "16331229+0934051",
#   "z": null,
#   "distance": null,
#   "B": 16.008,
#   "BErr": null,
#   "J": 14.122,
#   "JErr": 0.074,
#   "H": 13.255,
#   "HErr": 0.073,
#   "K": 12.824,
#   "KErr": 0.107,
#   "separationArcsec": 11.044859193191256,
#   "northSeparationArcsec": "3.294",
#   "eastSeparationArcsec": "10.542",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_glade_v2_3",
#   "transient_object_id": "ZTF21aanrvcq",
#   "catalogue_table_name": "The GLADE Catalogue v2.3",
#   "catalogue_table_id": 78,
#   "catalogue_view_id": 44,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "glade phot galaxy angular",
#   "raDeg": 248.301224,
#   "decDeg": 9.56811,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 2005.0
# }
# {
#   "catalogue_object_id": 119482483011342182,
#   "_g": 18.356800079345703,
#   "_gErr": 0.0014890000456944108,
#   "_r": 17.7992000579834,
#   "_rErr": 0.0009009999921545386,
#   "_i": 17.216999053955078,
#   "_iErr": 0.0006230000290088356,
#   "_z": 17.18429946899414,
#   "_zErr": 0.0009449999779462814,
#   "_y": 16.924999237060547,
#   "_yErr": 0.0008699999889358878,
#   "separationArcsec": 10.835575959919101,
#   "northSeparationArcsec": "3.08928",
#   "eastSeparationArcsec": "10.38586",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_ps1_dr1",
#   "transient_object_id": "ZTF21aanrvcq",
#   "catalogue_table_name": "PanSTARRS DR1",
#   "catalogue_table_id": 80,
#   "catalogue_view_id": 49,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "ps1 galaxy r angular",
#   "raDeg": 248.301179956,
#   "decDeg": 9.568053122,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 2005.0,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": 3,
#   "catalogue_object_id": 1237668272455156300,
#   "photoZ": 0.0397,
#   "photoZErr": 0.03,
#   "_u": 18.1397,
#   "_uErr": 0.157775,
#   "_g": 16.5025,
#   "_gErr": 0.228807,
#   "_r": 15.8248,
#   "_rErr": 0.365595,
#   "_i": 15.429,
#   "_iErr": 0.332062,
#   "_z": 15.221,
#   "_zErr": 0.284065,
#   "separationArcsec": 10.828509108273824,
#   "northSeparationArcsec": "3.09137",
#   "eastSeparationArcsec": "10.37786",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_sdss_photo_stars_galaxies_dr12",
#   "transient_object_id": "ZTF21aanrvcq",
#   "catalogue_table_name": "SDSS DR12 PhotoObjAll Table",
#   "catalogue_table_id": 47,
#   "catalogue_view_id": 13,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "sdss phot galaxy angular",
#   "raDeg": 248.30117770430184,
#   "decDeg": 9.56805370043946,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 2005.0
# }
# {
#   "catalogue_object_subtype": "G",
#   "catalogue_object_id": "1366952",
#   "z": null,
#   "distance": null,
#   "B": 16.96,
#   "BErr": 0.43,
#   "J": null,
#   "JErr": null,
#   "H": null,
#   "HErr": null,
#   "K": null,
#   "KErr": null,
#   "separationArcsec": 10.14845262426313,
#   "northSeparationArcsec": "2.8",
#   "eastSeparationArcsec": "9.7",
#   "association_type": "SN",
#   "catalogue_view_name": "tcs_view_galaxy_glade_v2_3",
#   "transient_object_id": "ZTF21aanrvcq",
#   "catalogue_table_name": "The GLADE Catalogue v2.3",
#   "catalogue_table_id": 78,
#   "catalogue_view_id": 44,
#   "classificationReliability": 2,
#   "scale": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "glade phot galaxy angular",
#   "raDeg": 248.301,
#   "decDeg": 9.56798,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 2005.0
# }
# {
#   "catalogue_object_id": "1237662237488906668",
#   "J": 14.594,
#   "JErr": 0.076,
#   "H": 13.902,
#   "HErr": 0.082,
#   "K": 14.041,
#   "KErr": 0.078,
#   "separationArcsec": 0.26995107619249054,
#   "northSeparationArcsec": "0.5089",
#   "eastSeparationArcsec": "0.0770",
#   "association_type": "NT",
#   "catalogue_view_name": "multiple",
#   "transient_object_id": "ZTF21aaqupdt",
#   "catalogue_table_name": "SDSS/2MASS/GLADE",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": 1.517825,
#   "distance": 365.4826076,
#   "distance_modulus": 37.8143336,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "multiple",
#   "raDeg": 236.76820923543005,
#   "decDeg": 6.110942130079035,
#   "original_search_radius_arcsec": "multiple",
#   "physical_separation_kpc": 0.4097384922218669,
#   "merged_rank": null,
#   "z": 0.0804631,
#   "photoZ": 0.067343,
#   "photoZErr": 0.019323,
#   "_r": 16.7408,
#   "_rErr": 0.0199717,
#   "_g": 17.5597,
#   "_gErr": 0.0221474,
#   "_i": 16.2813,
#   "_iErr": 0.0164076,
#   "_z": 15.9012,
#   "_zErr": 0.0301703,
#   "_u": 19.6068,
#   "_uErr": 0.240471,
#   "catalogue_object_subtype": "multiple",
#   "B": 17.254,
#   "BErr": null,
#   "rankScore": 952.0204869246111,
#   "rank": 1
# }
# {
#   "catalogue_object_id": "15470436+0606396 ",
#   "J": 15.578,
#   "JErr": 0.1,
#   "H": 14.677,
#   "HErr": 0.09,
#   "K": 14.041,
#   "KErr": 0.078,
#   "separationArcsec": 0.5146855727368181,
#   "northSeparationArcsec": "0.5089",
#   "eastSeparationArcsec": "0.0770",
#   "association_type": "VS",
#   "catalogue_view_name": "tcs_view_star_2mass_psc_final",
#   "transient_object_id": "ZTF21aaqupdt",
#   "catalogue_table_name": "2MASS PSC",
#   "catalogue_table_id": 1,
#   "catalogue_view_id": 20,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "star",
#   "search_name": "2mass star angular",
#   "raDeg": 236.768194,
#   "decDeg": 6.111018,
#   "original_search_radius_arcsec": 2.5,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 952.0204869246111,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": 3,
#   "catalogue_object_id": 1237662237488906668,
#   "photoZ": 0.067343,
#   "photoZErr": 0.019323,
#   "_u": 19.6068,
#   "_uErr": 0.240471,
#   "_g": 17.5597,
#   "_gErr": 0.0221474,
#   "_r": 16.7408,
#   "_rErr": 0.0199717,
#   "_i": 16.2813,
#   "_iErr": 0.0164076,
#   "_z": 15.9012,
#   "_zErr": 0.0301703,
#   "separationArcsec": 0.26995107619249054,
#   "northSeparationArcsec": "0.2357582845",
#   "eastSeparationArcsec": "0.1315259063",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_sdss_photo_stars_galaxies_dr12",
#   "transient_object_id": "ZTF21aaqupdt",
#   "catalogue_table_name": "SDSS DR12 PhotoObjAll Table",
#   "catalogue_table_id": 47,
#   "catalogue_view_id": 13,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "sdss phot galaxy angular",
#   "raDeg": 236.76820923543005,
#   "decDeg": 6.110942130079035,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 952.0204869246111
# }
# {
#   "catalogue_object_subtype": 3,
#   "catalogue_object_id": 1237662237488906668,
#   "z": 0.0804631,
#   "_u": 19.6068,
#   "_uErr": 0.240471,
#   "_g": 17.5597,
#   "_gErr": 0.0221474,
#   "_r": 16.7408,
#   "_rErr": 0.0199717,
#   "_i": 16.2813,
#   "_iErr": 0.0164076,
#   "_z": 15.9012,
#   "_zErr": 0.0301703,
#   "separationArcsec": 0.26995107619249054,
#   "northSeparationArcsec": "0.2357582845",
#   "eastSeparationArcsec": "0.1315259063",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_sdss_spect_galaxies_qsos_dr12",
#   "transient_object_id": "ZTF21aaqupdt",
#   "catalogue_table_name": "SDSS DR12 SpecObjAll Table",
#   "catalogue_table_id": 48,
#   "catalogue_view_id": 14,
#   "classificationReliability": 1,
#   "scale": 1.517825,
#   "distance": 365.4826076,
#   "distance_modulus": 37.8143336,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "sdss spec sn physical (redshift distance)",
#   "raDeg": 236.76820923543005,
#   "decDeg": 6.110942130079035,
#   "original_search_radius_arcsec": 32.94187406321546,
#   "physical_separation_kpc": 0.4097384922218669,
#   "merged_rank": 1,
#   "rankScore": 952.0204869246111
# }
# {
#   "catalogue_object_id": "15470439+0606396",
#   "J": 14.497,
#   "JErr": 0.13,
#   "H": 13.762,
#   "HErr": 0.151,
#   "K": 12.773,
#   "KErr": 0.116,
#   "separationArcsec": 0.6777516558188306,
#   "northSeparationArcsec": "0.462",
#   "eastSeparationArcsec": "0.496",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_2mass_xsc_final",
#   "transient_object_id": "ZTF21aaqupdt",
#   "catalogue_table_name": "2MASS XSC",
#   "catalogue_table_id": 2,
#   "catalogue_view_id": 10,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "2mass galaxy angular",
#   "raDeg": 236.768311,
#   "decDeg": 6.111005,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 952.0204869246111,
#   "catalogue_object_subtype": null
# }
# {
#   "catalogue_object_subtype": "G",
#   "catalogue_object_id": "1294734",
#   "z": null,
#   "distance": null,
#   "B": 17.254,
#   "BErr": null,
#   "J": 14.594,
#   "JErr": 0.076,
#   "H": 13.902,
#   "HErr": 0.082,
#   "K": 13.27,
#   "KErr": 0.099,
#   "separationArcsec": 0.6777516558188306,
#   "northSeparationArcsec": "0.462",
#   "eastSeparationArcsec": "0.496",
#   "association_type": "NT",
#   "catalogue_view_name": "tcs_view_galaxy_glade_v2_3",
#   "transient_object_id": "ZTF21aaqupdt",
#   "catalogue_table_name": "The GLADE Catalogue v2.3",
#   "catalogue_table_id": 78,
#   "catalogue_view_id": 44,
#   "classificationReliability": 1,
#   "scale": null,
#   "distance_modulus": null,
#   "major_axis_arcsec": null,
#   "direct_distance": null,
#   "direct_distance_scale": null,
#   "direct_distance_modulus": null,
#   "catalogue_object_type": "galaxy",
#   "search_name": "glade phot galaxy angular",
#   "raDeg": 236.768311,
#   "decDeg": 6.111005,
#   "original_search_radius_arcsec": 35.0,
#   "physical_separation_kpc": null,
#   "merged_rank": 1,
#   "rankScore": 952.0204869246111
# }
# 49

# %% [markdown]
# ### Finally - Sherlock by Position
# OK - let's try and grab Sherlock information for a star we KNOW can't be in ZTF.  What about alpha Crux.

# %%
# This is ACrux.
ra = 186.64956341666667
dec = -63.09909286111111

try:
    result = L.sherlock_position(ra, dec, lite = True)
except LasairError as e:
    print(e)

print(json.dumps(result, indent=2))
# Out:
# {
#   "classifications": {
#     "transient_00000": [
#       "VS",
#       "The transient is synonymous with <em>S7LH000444</em>; a V=1.28 mag stellar source found in the GSC catalogue. It's located 0.0\" from the stellar source core."
#     ]
#   },
#   "crossmatches": [
#     {
#       "transient_object_id": "transient_00000",
#       "association_type": "VS",
#       "catalogue_table_name": "GSC",
#       "catalogue_object_id": "S7LH000444",
#       "catalogue_object_type": "star",
#       "raDeg": 186.64956583949925,
#       "decDeg": -63.09909166644884,
#       "separationArcsec": 0.01,
#       "northSeparationArcsec": "0.0048",
#       "eastSeparationArcsec": "0.0046",
#       "physical_separation_kpc": null,
#       "direct_distance": null,
#       "distance": null,
#       "z": null,
#       "photoZ": null,
#       "photoZErr": null,
#       "Mag": 1.28,
#       "MagFilter": "V",
#       "MagErr": 0.01,
#       "classificationReliability": 1
#     }
#   ]
# }
